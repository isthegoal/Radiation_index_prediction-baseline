# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold
import lightgbm as lgb
from lightgbm import plot_importance
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sklearn
import time
import random
import operator
from sklearn.model_selection import StratifiedKFold
from pandas import DataFrame as DF
#先一个人观察，再说，胸有竹再讨论   各自做EDA吧

# %%
print('-----  加载非叠加式数据  -----')
train = pd.read_csv( '../data/train_feature.csv')
train_label = pd.read_csv('../data/train_label.csv')
test = pd.read_csv( '../data/test_feature.csv')
print('-----  加载叠加式数据  -----')
train_flat = pd.read_csv( '../data/extract_train_data.csv')
test_flat = pd.read_csv( '../data/extract_test_data.csv')

print(train.columns)
print(train_flat.columns)
print(train.head())
print(train_flat.head())
# Out:
# -----  加载非叠加式数据  -----
# -----  加载叠加式数据  -----
# Index(['日期', '时刻', '辐照度', '风速', '风向', '温度', '湿度', '气压'], dtype='object')
# Index(['Unnamed: 0', '辐照度2', '风速2', '风向2', '温度2', '湿度2', '气压2', '辐照度5', '风速5',
#        '风向5', '温度5', '湿度5', '气压5', '辐照度8', '风速8', '风向8', '温度8', '湿度8', '气压8',
#        '辐照度11', '风速11', '风向11', '温度11', '湿度11', '气压11', '辐照度14', '风速14',
#        '风向14', '温度14', '湿度14', '气压14', '辐照度17', '风速17', '风向17', '温度17', '湿度17',
#        '气压17', '辐照度20', '风速20', '风向20', '温度20', '湿度20', '气压20', '辐照度23',
#        '风速23', '风向23', '温度23', '湿度23', '气压23', 'label'],
#       dtype='object')
#    日期  时刻  辐照度   风速   风向    温度  湿度     气压
# 0   1   2    0  2.1  343  -7.2  51  69800
# 1   1   5    0  3.6  279  -9.4  64  69800
# 2   1   8    0  2.6  270 -10.1  61  69900
# 3   1  11  333  1.4  266  -4.2  38  70000
# 4   1  14  489  0.0    0  -0.2  26  69800
#    Unnamed: 0  辐照度2  风速2    风向2  温度2   湿度2      气压2  辐照度5  风速5    风向5  \
# ...

# %% [markdown]
# # 天数统计
#    训练集：
#
#         一号站点：第1天到401
#         二号站点：第402天到835
#         三号站点：第836天到1263
#         四号站点：第1264天到1694
#         五号站点：第1695天到2126
#    测试集：
#
#         一号站点：第1天到173
#         二号站点：第174天到356
#         三号站点：第357天到543
#         四号站点：第544天到726
#         五号站点：第727天到915
#
#   从对每天8点的辐照度情况可以发现，训练集和测试集的站点出现情况是一致的，也就是说是按照一定的固定循序出现的。那么就可以把站点序号当做固定的特征了。

# %%
print('第一天的辐照度数值变化',(train[train['日期']==1])['辐照度'])
# for i in range(1,2126):
#     (train[train['日期']==i])['温度'].plot()
# plt.show()
# for i in range(1,915):
#     (test[test['日期']==i])['温度'].plot()
# plt.show()
#实验测试集的  不同站点的分离序号
for i in range(727,916):
    (test[test['日期']==i])['温度'].plot()
# Out:
# 第一天的辐照度数值变化 0      0
# 1      0
# 2      0
# 3    333
# 4    489
# 5    186
# 6      0
# 7      0
# Name: 辐照度, dtype: int64

# %% [markdown]
# 从上面温度图可以捕捉到测试集的站点分类需要，其中不同的5个站点分类序号
# 测试集：
#
#     一号站点：第1天到173
#     二号站点：第174天到356
#     三号站点：第357天到543
#     四号站点：第544天到726
#     五号站点：第727天到915

# %%
# print('第一天的辐照度数值变化',(train[train['日期']==1])['辐照度'])
for i in range(1,2126):
    (train[train['日期']==i])['辐照度'].plot()
plt.show()

# %%
# for i in range(1,915):
#     (test[test['日期']==i])['辐照度'].plot()
# plt.ylim(600,1000)    
#测试不同电厂的展示天数
for i in range(1695,2126):
    (train[train['日期']==i])['辐照度'].plot()
plt.show()
# for i in range(430,870):
#     (train[train['日期']==i])['辐照度'].plot()
# plt.show()
# for i in range(870,1290):
#     (train[train['日期']==i])['辐照度'].plot()
# plt.show()

# %% [markdown]
# 从辐照度变化，可以分离出训练集中不同电厂的包含时间
# 训练集中：
#
#     一号站点：第1天到401
#     二号站点：第402天到835
#     三号站点：第836天到1263
#     四号站点：第1264天到1694
#     五号站点：第1695天到2126

# %%
print('第一天的辐照度数值变化',(train[train['日期']==1])['辐照度'])
for i in range(1,520):
    (train[train['日期']==i])['气压'].plot()
plt.show()
for i in range(1,520):
    (test[test['日期']==i])['气压'].plot()
plt.ylim(68000,71000)
# Out:
# 第一天的辐照度数值变化 0      0
# 1      0
# 2      0
# 3    333
# 4    489
# 5    186
# 6      0
# 7      0
# Name: 辐照度, dtype: int64
# (68000, 71000)

# %%
print('第一天的辐照度数值变化',(train[train['日期']==1])['辐照度'])
for i in range(1,520):
    (train[train['日期']==i])['湿度'].plot()
plt.show()
for i in range(1,520):
    (test[test['日期']==i])['湿度'].plot()
#plt.ylim(68000,71000)
# Out:
# 第一天的辐照度数值变化 0      0
# 1      0
# 2      0
# 3    333
# 4    489
# 5    186
# 6      0
# 7      0
# Name: 辐照度, dtype: int64

# %%
2126/5
# Out:
# 425.2

# %%
915/5
# Out:
# 183.0

# %%
#'辐照度2', '风速2', '风向2', '温度2', '湿度2', '气压2', '辐照度5', '风速5', '风向5', '温度5', '湿度5', '气压5', '辐照度8', '风速8', '风向8', '温度8', '湿度8', '气压8',
# 2 5 8 11 14 17  20 23
#train_flat['辐照度8'].plot()

train_flat['辐照度8'].plot()
plt.show()
test_flat['辐照度8'].plot()

# %% [markdown]
# 可以发现测试集是没有冬季的，也就是冬季在早上八点时候的辐照度会有为0的时候，可以知道每个站点应该是成年的多一点
# 可以推测：
#
#
#       训练集是成年的，从春天到冬天多一点。   （平均下来每个站点大约425.2）
#       测试集是一年的春天到秋天    （平均下来每个站点大约183.0）

# %%
print('-------  绘制8个时刻6种指标分别的变化图  --------')
for  i in  ['2','5','8','11','14','17','20','23']:
    for j in [ '辐照度', '风速', '风向', '温度', '湿度', '气压']:
        print('-----------'+'   '+i+'时刻的'+j+'   '+'-----------')
        train_flat[j+i].plot()
        plt.show()
        test_flat[j+i].plot()
        plt.show()
# train_flat['温度14'].plot()
# plt.show()
# test_flat['温度14'].plot()
# Out:
# -------  绘制8个时刻6种指标的变化图  --------
# -----------   2时刻的辐照度   -----------
# -----------   2时刻的风速   -----------
# -----------   2时刻的风向   -----------
# -----------   2时刻的温度   -----------
# -----------   2时刻的湿度   -----------
# -----------   2时刻的气压   -----------
# -----------   5时刻的辐照度   -----------
# -----------   5时刻的风速   -----------
# -----------   5时刻的风向   -----------
# -----------   5时刻的温度   -----------
# -----------   5时刻的湿度   -----------
# -----------   5时刻的气压   -----------
# -----------   8时刻的辐照度   -----------
# -----------   8时刻的风速   -----------
# -----------   8时刻的风向   -----------
# -----------   8时刻的温度   -----------
# -----------   8时刻的湿度   -----------
# -----------   8时刻的气压   -----------
# -----------   11时刻的辐照度   -----------
# -----------   11时刻的风速   -----------
# -----------   11时刻的风向   -----------
# -----------   11时刻的温度   -----------
# -----------   11时刻的湿度   -----------
# -----------   11时刻的气压   -----------
# -----------   14时刻的辐照度   -----------
# ...

# %% [markdown]
# 对上面每个的观察发现：
#     1.气压、风速存在突变值，也就是异常值、很少存在缺失点。

# %%
print('-------  绘制6种指标的变化图  --------')
for j in [ '辐照度', '风速', '风向', '温度', '湿度', '气压']:
    print('-----------'+'   '+'指标：'+j+'   '+'-----------')
    train[j].plot()
    plt.show()
    test[j].plot()
    plt.show()
# Out:
# -------  绘制6种指标的变化图  --------
# -----------   指标：辐照度   -----------
# -----------   指标：风速   -----------
# -----------   指标：风向   -----------
# -----------   指标：温度   -----------
# -----------   指标：湿度   -----------
# -----------   指标：气压   -----------
